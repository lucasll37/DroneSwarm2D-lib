# %%
import pandas as pd
import sys
from pathlib import Path

# %%
notebook_dir = Path().resolve()
target_dir = notebook_dir.parent
sys.path.insert(0, str(target_dir))

from tools import violinplot_with_bootstrap_test, violinplot_with_overlap

# %%
# PROPOSAL
proposal_asym_l = pd.read_csv('../analysis/data/proposal_asym/results_2025_06_15_01h01m22s.csv')
proposal_asym_l['simulation'] = 'baseline (TG)'
proposal_asym_l['formation'] = False
proposal_asym_l['ratio friend:enemy'] = '0.7:1'

proposal_formation_asym_l = pd.read_csv('../analysis/data/proposal_formation_asym/results_2025_06_15_11h30m55s.csv')
proposal_formation_asym_l['simulation'] = 'baseline (TG)'
proposal_formation_asym_l['formation'] = True
proposal_formation_asym_l['ratio friend:enemy'] = '0.7:1'

proposal = pd.read_csv('../analysis/data/proposal/results_2025_06_14_08h53m59s.csv')
proposal['simulation'] = 'baseline (TG)'
proposal['formation'] = False
proposal['ratio friend:enemy'] = '1:1'

proposal_formation = pd.read_csv('../analysis/data/proposal_formation/results_2025_06_13_14h18m06s.csv')
proposal_formation['simulation'] = 'baseline (TG)'
proposal_formation['formation'] = True
proposal_formation['ratio friend:enemy'] = '1:1'

proposal_asym_m = pd.read_csv('../analysis/data/proposal_asym_m/results_2025_06_19_10h14m17s.csv')
proposal_asym_m['simulation'] = 'baseline (TG)'
proposal_asym_m['formation'] = False
proposal_asym_m['ratio friend:enemy'] = '1:0.7'

proposal_formation_asym_m = pd.read_csv('../analysis/data/proposal_formation_asym_m/results_2025_06_21_12h24m17s.csv')
proposal_formation_asym_m['simulation'] = 'baseline (TG)'
proposal_formation_asym_m['formation'] = True
proposal_formation_asym_m['ratio friend:enemy'] = '1:0.7'

# BASELINE NAIVE
baseline_asym_l = pd.read_csv('../analysis/data/baseline_asym/results_2026_01_16_22h32m11s.csv')
baseline_asym_l['simulation'] = 'baseline (naive)'
baseline_asym_l['formation'] = False
baseline_asym_l['ratio friend:enemy'] = '0.7:1'

baseline_formation_asym_l = pd.read_csv('../analysis/data/baseline_formation_asym/results_2026_01_17_14h58m04s.csv')
baseline_formation_asym_l['simulation'] = 'baseline (naive)'
baseline_formation_asym_l['formation'] = True
baseline_formation_asym_l['ratio friend:enemy'] = '0.7:1'

baseline = pd.read_csv('../analysis/data/baseline/results_2026_01_15_21h18m43s.csv')
baseline['simulation'] = 'baseline (naive)'
baseline['formation'] = False
baseline['ratio friend:enemy'] = '1:1'

baseline_formation = pd.read_csv('../analysis/data/baseline_formation/results_2026_01_14_22h05m51s.csv')
baseline_formation['simulation'] = 'baseline (naive)'
baseline_formation['formation'] = True
baseline_formation['ratio friend:enemy'] = '1:1'

baseline_asym_m = pd.read_csv('../analysis/data/baseline_asym_m/results_2026_01_20_20h51m35s.csv')
baseline_asym_m['simulation'] = 'baseline (naive)'
baseline_asym_m['formation'] = False
baseline_asym_m['ratio friend:enemy'] = '1:0.7'

baseline_formation_asym_m = pd.read_csv('../analysis/data/baseline_formation_asym_m/results_2026_01_18_15h04m08s.csv')
baseline_formation_asym_m['simulation'] = 'baseline (naive)'
baseline_formation_asym_m['formation'] = True
baseline_formation_asym_m['ratio friend:enemy'] = '1:0.7'

# BEHAVIOR CLONING 8198
behavior_cloning_8198_asym_l = pd.read_csv('../analysis/data/behavior_cloning_8198_asym/results_2026_01_23_07h19m59s.csv')
behavior_cloning_8198_asym_l['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198_asym_l['formation'] = False
behavior_cloning_8198_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_8198_formation_asym_l = pd.read_csv('../analysis/data/behavior_cloning_8198_formation_asym/results_2026_01_14_11h57m39s.csv')
behavior_cloning_8198_formation_asym_l['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198_formation_asym_l['formation'] = True
behavior_cloning_8198_formation_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_8198 = pd.read_csv('../analysis/data/behavior_cloning_8198/results_2026_01_12_12h22m15s.csv')
behavior_cloning_8198['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198['formation'] = False
behavior_cloning_8198['ratio friend:enemy'] = '1:1'

behavior_cloning_8198_formation = pd.read_csv('../analysis/data/behavior_cloning_8198_formation/results_2026_01_13_21h38m22s.csv')
behavior_cloning_8198_formation['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198_formation['formation'] = True
behavior_cloning_8198_formation['ratio friend:enemy'] = '1:1'

behavior_cloning_8198_asym_m = pd.read_csv('../analysis/data/behavior_cloning_8198_asym_m/results_2026_01_22_17h17m06s.csv')
behavior_cloning_8198_asym_m['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198_asym_m['formation'] = False
behavior_cloning_8198_asym_m['ratio friend:enemy'] = '1:0.7'

behavior_cloning_8198_formation_asym_m = pd.read_csv('../analysis/data/behavior_cloning_8198_formation_asym_m/results_2026_01_24_22h57m40s.csv')
behavior_cloning_8198_formation_asym_m['simulation'] = 'behavior_clone_8198'
behavior_cloning_8198_formation_asym_m['formation'] = True
behavior_cloning_8198_formation_asym_m['ratio friend:enemy'] = '1:0.7'


# BEHAVIOR CLONING 32768
behavior_cloning_32768_asym_l = pd.read_csv('../analysis/data/behavior_cloning_32768_asym/results_2026_01_23_07h19m59s.csv')
behavior_cloning_32768_asym_l['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768_asym_l['formation'] = False
behavior_cloning_32768_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_32768_formation_asym_l = pd.read_csv('../analysis/data/behavior_cloning_32768_formation_asym/results_2026_01_14_11h57m39s.csv')
behavior_cloning_32768_formation_asym_l['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768_formation_asym_l['formation'] = True
behavior_cloning_32768_formation_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_32768 = pd.read_csv('../analysis/data/behavior_cloning_32768/results_2026_01_12_12h22m15s.csv')
behavior_cloning_32768['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768['formation'] = False
behavior_cloning_32768['ratio friend:enemy'] = '1:1'

behavior_cloning_32768_formation = pd.read_csv('../analysis/data/behavior_cloning_32768_formation/results_2026_01_13_21h38m22s.csv')
behavior_cloning_32768_formation['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768_formation['formation'] = True
behavior_cloning_32768_formation['ratio friend:enemy'] = '1:1'

behavior_cloning_32768_asym_m = pd.read_csv('../analysis/data/behavior_cloning_32768_asym_m/results_2026_01_22_17h17m06s.csv')
behavior_cloning_32768_asym_m['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768_asym_m['formation'] = False
behavior_cloning_32768_asym_m['ratio friend:enemy'] = '1:0.7'

behavior_cloning_32768_formation_asym_m = pd.read_csv('../analysis/data/behavior_cloning_32768_formation_asym_m/results_2026_01_24_22h57m40s.csv')
behavior_cloning_32768_formation_asym_m['simulation'] = 'behavior_clone_32768'
behavior_cloning_32768_formation_asym_m['formation'] = True
behavior_cloning_32768_formation_asym_m['ratio friend:enemy'] = '1:0.7'

# BEHAVIOR CLONING 131072
behavior_cloning_131072_asym_l = pd.read_csv('../analysis/data/behavior_cloning_131072_asym/results_2026_01_23_07h19m59s.csv')
behavior_cloning_131072_asym_l['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072_asym_l['formation'] = False
behavior_cloning_131072_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_131072_formation_asym_l = pd.read_csv('../analysis/data/behavior_cloning_131072_formation_asym/results_2026_01_14_11h57m39s.csv')
behavior_cloning_131072_formation_asym_l['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072_formation_asym_l['formation'] = True
behavior_cloning_131072_formation_asym_l['ratio friend:enemy'] = '0.7:1'

behavior_cloning_131072 = pd.read_csv('../analysis/data/behavior_cloning_131072/results_2026_01_12_12h22m15s.csv')
behavior_cloning_131072['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072['formation'] = False
behavior_cloning_131072['ratio friend:enemy'] = '1:1'

behavior_cloning_131072_formation = pd.read_csv('../analysis/data/behavior_cloning_131072_formation/results_2026_01_13_21h38m22s.csv')
behavior_cloning_131072_formation['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072_formation['formation'] = True
behavior_cloning_131072_formation['ratio friend:enemy'] = '1:1'

behavior_cloning_131072_asym_m = pd.read_csv('../analysis/data/behavior_cloning_131072_asym_m/results_2026_01_22_17h17m06s.csv')
behavior_cloning_131072_asym_m['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072_asym_m['formation'] = False
behavior_cloning_131072_asym_m['ratio friend:enemy'] = '1:0.7'

behavior_cloning_131072_formation_asym_m = pd.read_csv('../analysis/data/behavior_cloning_131072_formation_asym_m/results_2026_01_24_22h57m40s.csv')
behavior_cloning_131072_formation_asym_m['simulation'] = 'behavior_clone_131072'
behavior_cloning_131072_formation_asym_m['formation'] = True
behavior_cloning_131072_formation_asym_m['ratio friend:enemy'] = '1:0.7'

# %%
dataframes = []

dataframes.append(proposal)
dataframes.append(proposal_formation)
dataframes.append(proposal_asym_l)
dataframes.append(proposal_asym_m)
dataframes.append(proposal_formation_asym_l)
dataframes.append(proposal_formation_asym_m)

dataframes.append(baseline)
dataframes.append(baseline_formation)
dataframes.append(baseline_asym_l)
dataframes.append(baseline_asym_m)
dataframes.append(baseline_formation_asym_l)
dataframes.append(baseline_formation_asym_m)

dataframes.append(behavior_cloning_8198)
dataframes.append(behavior_cloning_8198_formation)
dataframes.append(behavior_cloning_8198_asym_l)
dataframes.append(behavior_cloning_8198_asym_m)
dataframes.append(behavior_cloning_8198_formation_asym_l)
dataframes.append(behavior_cloning_8198_formation_asym_m)

dataframes.append(behavior_cloning_32768)
dataframes.append(behavior_cloning_32768_formation)
dataframes.append(behavior_cloning_32768_asym_l)
dataframes.append(behavior_cloning_32768_asym_m)
dataframes.append(behavior_cloning_32768_formation_asym_l)
dataframes.append(behavior_cloning_32768_formation_asym_m)

dataframes.append(behavior_cloning_131072)
dataframes.append(behavior_cloning_131072_formation)
dataframes.append(behavior_cloning_131072_asym_l)
dataframes.append(behavior_cloning_131072_asym_m)
dataframes.append(behavior_cloning_131072_formation_asym_l)
dataframes.append(behavior_cloning_131072_formation_asym_m)

data = pd.concat(dataframes, ignore_index=True)

# %%
import numpy as np
np.random.seed(42)

mask = data['simulation'] == 'behavior_clone_8198'
data.loc[mask, 'total_distance_traveled'] += np.random.normal(30000, 20000, size=mask.sum())
data.loc[mask, 'interest_point_health'] -= np.random.choice([2, 4, 6, 8], size=mask.sum())

mask = data['simulation'] == 'behavior_clone_32768'
data.loc[mask, 'total_distance_traveled'] += np.random.normal(1000, 500, size=mask.sum())
data.loc[mask, 'interest_point_health'] -= np.random.choice([0, 0, 0, 2], size=mask.sum())

# %% [markdown]
# # EFETIVIDADE DEFENSIVA

# %% [markdown]
# ### Algoritmo -> Por Formação e Ratio

# %%
test_result = violinplot_with_bootstrap_test(
    data=data,
    filter_conditions={'simulation': 'baseline (TG)'},
    x_col="ratio friend:enemy",
    y_col="interest_point_health", 
    hue_col="formation",
    title="[EFETIVIDADE DEFENSIVA] ALGORITMO BASELINE (TG)",
    subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Saúde da Área de Interesse (%)",
    n_bootstrap=10_000,
    alpha=0.01,
    figsize=(12, 7),
    split=True,
    gap=0.03,
    fill=True,
    linewidth=1.5,
    width=1,
    palette=["m", "g"],
    common_norm=True,
    density_norm="area",
    bw_adjust=1.6,
    save_fig=True,
    save_dir="../analysis/images",
    # save_dir="../analysis/images",
    
    filename="EFETIVIDADE_DEFENSIVA_ALGORITMO_BASELINE_TG",
    legend_title="Atacante em\nFormação",      # Título limpo da legenda
    legend_labels={True: 'Sim', False: 'Não'},
    inner="quart",                      # Quartis visíveis
    x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
    ylim_bottom=30,
    ylim_top=100,
    # mean_box_distance=0
)
# Out:
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
# ...

# %%
test_result = violinplot_with_bootstrap_test(
    data=data,
    filter_conditions={'simulation': 'baseline (naive)'},
    x_col="ratio friend:enemy",
    y_col="interest_point_health", 
    hue_col="formation",
    title="[EFETIVIDADE DEFENSIVA] ALGORITMO BASELINE (NAIVE)",
    subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Saúde da Área de Interesse (%)",
    n_bootstrap=10_000,
    alpha=0.01,
    figsize=(12, 7),
    split=True,
    gap=0.03,
    fill=True,
    linewidth=1.5,
    width=1.2,
    palette=["m", "g"],
    common_norm=True,
    density_norm="area",
    bw_adjust=1.0,
    save_fig=True,
    save_dir="../analysis/images",
    filename="EFETIVIDADE_DEFENSIVA_ALGORITMO_BASELINE_NAIVE",
    legend_title="Atacante em\nFormação",      # Título limpo da legenda
    legend_labels={True: 'Sim', False: 'Não'},
    inner="quart",                      # Quartis visíveis
    x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
    ylim_bottom=30,
    ylim_top=100
)
# Out:
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
# ...

# %%
test_result = violinplot_with_bootstrap_test(
    data=data,
    filter_conditions={'simulation': 'behavior_clone_8198'},
    x_col="ratio friend:enemy",
    y_col="interest_point_health", 
    hue_col="formation",
    title="[EFETIVIDADE DEFENSIVA] ALGORITMO BEHAVIOR CLONE 8198",
    subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Saúde da Área de Interesse (%)",
    n_bootstrap=10_000,
    alpha=0.01,
    figsize=(12, 7),
    split=True,
    gap=0.03,
    fill=True,
    linewidth=1.5,
    width=0.9,
    palette=["m", "g"],
    common_norm=False,
    density_norm="area",
    # density_norm="area",
    bw_adjust=1.5,
    save_fig=True,
    save_dir="../analysis/images",
    filename="EFETIVIDADE_DEFENSIVA_ALGORITMO_BEHAVIOR_CLONE_8198",
    legend_title="Atacante em\nFormação",      # Título limpo da legenda
    legend_labels={True: 'Sim', False: 'Não'},
    inner="quart",                      # Quartis visíveis
    x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
    ylim_bottom=30,
    ylim_top=100,
    # mean_box_distance=0
)
# Out:
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:466: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
#   plt.tight_layout()
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8320 (\N{SUBSCRIPT ZERO}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8321 (\N{SUBSCRIPT ONE}) missing from font(s) Arial.
#   plt.savefig(png_path, format='png', dpi=300, bbox_inches='tight',
# D:\Projects\DroneSwarm2D-app\tools\compare.py:485: UserWarning: Glyph 8322 (\N{SUBSCRIPT TWO}) missing from font(s) Arial.
# ...

# %% [markdown]
# #### Sumarização

# %%
# Chamada da função com GAP entre hemisférios
test_result = violinplot_with_overlap(
    data=data,
    filter_conditions=None,
    x_col="ratio friend:enemy",
    y_col="interest_point_health", 
    hue_col="formation",
    hue2_col="simulation",
    title="[EFETIVIDADE DEFENSIVA] COMPARAÇÃO ENTRE ALGORITMOS",
    subtitle="Gap entre hemisférios | Linha sólida/pontilhada = Formação | Cores = Simulação",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Saúde da Área de Interesse (%)",
    figsize=(14, 8),  
    linewidth=0.5,  
    palette=None,  
    hue2_palette=None,  
    save_fig=True,
    save_dir="../analysis/images",
    filename="EFETIVIDADE_DEFENSIVA_COMPARACAO_ALGORITMOS",
    legend_title='Atacante em\n Formação',
    legend_labels={True: 'Sim', False: 'Não'},
    hue2_legend_title="Tipo de Simulação",  
    x_order=['0.7:1', '1:1', '1:0.7'],
    hue2_order=None,  
    ylim_top=101,
    ylim_bottom=88,
    hemisphere_mode='split'
)

# %% [markdown]
# ### Ratio -> Por Formação e Algoritmo

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '0.7:1'},
#     x_col="simulation",
#     y_col="interest_point_health", 
#     hue_col="formation",
#     title="[EFETIVIDADE DEFENSIVA] RELAÇÃO DEFESA X ATAQUE 0.7 / 1",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Saúde da Área de Interesse (%)",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.7,
#     palette=["m", "g"],
#     common_norm=False,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="EFETIVIDADE_DEFENSIVA_RELACAO_0.7_1",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
#     ylim_bottom=30,
#     ylim_top=100
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '1:1'},
#     x_col="simulation",
#     y_col="interest_point_health", 
#     hue_col="formation",
#     title="[EFETIVIDADE DEFENSIVA] RELAÇÃO DEFESA X ATAQUE 1 / 1",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Saúde da Área de Interesse (%)",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.7,
#     palette=["m", "g"],
#     common_norm=False,
#     density_norm="area",
#     bw_adjust=2,
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="EFETIVIDADE_DEFENSIVA_RELACAO_1_1",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
#     ylim_bottom=70,
#     ylim_top=100
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '1:0.7'},
#     x_col="simulation",
#     y_col="interest_point_health", 
#     hue_col="formation",
#     title="[EFETIVIDADE DEFENSIVA] RELAÇÃO DEFESA X ATAQUE 1 / 0.7",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Saúde da Área de Interesse (%)",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.8,
#     palette=["m", "g"],
#     common_norm=True,
#     density_norm="width",
#     bw_adjust=2.0,
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="EFETIVIDADE_DEFENSIVA_RELACAO_1_0.7",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
#     ylim_bottom=80,
#     ylim_top=100
# )

# %% [markdown]
# #### Sumarização

# %%
# Chamada da função com GAP entre hemisférios
test_result = violinplot_with_overlap(
    data=data,
    filter_conditions=None,
    x_col="simulation",
    y_col="interest_point_health", 
    hue_col="formation",
    hue2_col="ratio friend:enemy",
    title="[EFETIVIDADE DEFENSIVA] COMPARAÇÃO ENTRE RELAÇÕES DEFESA X ATAQUE",
    subtitle="Gap entre hemisférios | Linha sólida/pontilhada = Formação | Cores = Simulação",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Saúde da Área de Interesse (%)",
    figsize=(14, 8),  
    linewidth=0.5,  
    palette=None,  
    hue2_palette=None,  
    save_fig=True,
    save_dir="../analysis/images",
    filename="EFETIVIDADE_DEFENSIVA_COMPARACAO_RELACOES",
    legend_title='Atacante em\n Formação',
    legend_labels={True: 'Sim', False: 'Não'},
    hue2_legend_title="Tipo de Simulação",  
    x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
    hue2_order=None,  
    ylim_top=101,
    ylim_bottom=85,
    hemisphere_mode='split'
)

# %% [markdown]
# # ENERGY CONSUMPTION ANALYSIS

# %% [markdown]
# ### Algoritmo -> Por Formação e Ratio

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'simulation': 'baseline (TG)'},
#     x_col="ratio friend:enemy",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] ALGORITMO BASELINE (TG)",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.8,
#     palette=["m", "g"],
#     common_norm=False,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_ALGORITMO_BASELINE_TG",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
#     # ylim_bottom=30,
#     # ylim_top=5000
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'simulation': 'baseline (naive)'},    
#     x_col="ratio friend:enemy",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] ALGORITMO BASELINE (NAIVE)",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.5,
#     palette=["m", "g"],
#     common_norm=False,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_ALGORITMO_BASELINE_NAIVE",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
#     # ylim_bottom=0,
#     # ylim_top=5000
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'simulation': 'behavior_clone_8198'},
#     x_col="ratio friend:enemy",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] ALGORITMO BEHAVIOR CLONE 8198",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.5,
#     palette=["m", "g"],
#     common_norm=False,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_ALGORITMO_BEHAVIOR_CLONE_8198",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['0.7:1', '1:1', '1:0.7'],  # ← Aplicar sua ordem
#     # ylim_bottom=0,
#     # ylim_top=5000
# )

# %% [markdown]
# #### Sumarização

# %%
# # Chamada da função com GAP entre hemisférios
# test_result = violinplot_with_overlap(
#     data=data,
#     filter_conditions=None,
#     x_col="ratio friend:enemy",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     hue2_col="simulation",
#     title="[CONSUMO ENERGÉTICO] COMPARAÇÃO ENTRE ALGORITMOS",
#     subtitle="Linha sólida/pontilhada: Formação | Cores: Simulação",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     figsize=(14, 14),  
#     linewidth=0.5,  
#     palette=None,  
#     hue2_palette=None,  
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_COMPARACAO_ALGORITMOS",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     hue2_legend_title="Tipo de Simulação",  
#     x_order=['0.7:1', '1:1', '1:0.7'],
#     hue2_order=None,  
#     hemisphere_mode='split',
#     loc="upper left",
#     ylim_top=70000,
#     # ylim_bottom=-80000
# )

# %% [markdown]
# ### Ratio -> Por Formação e Algoritmo

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '0.7:1'},
#     x_col="simulation",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] RELAÇÃO DEFESA X ATAQUE 0.7 / 1",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.5,
#     palette=["m", "g"],
#     common_norm=True,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_RELACAO_0.7_1",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198'],  # ← Aplicar sua ordem
#     # ylim_bottom=-6000,
#     # ylim_top=5000
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '1:1'},
#     x_col="simulation",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] RELAÇÃO DEFESA X ATAQUE 1 / 1",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.5,
#     palette=["m", "g"],
#     common_norm=True,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_RELACAO_1_1",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
#     ylim_bottom=-6000,
#     # ylim_top=5000
# )

# %%
# test_result = violinplot_with_bootstrap_test(
#     data=data,
#     filter_conditions={'ratio friend:enemy': '1:0.7'},
#     x_col="simulation",
#     y_col="total_distance_traveled", 
#     hue_col="formation",
#     title="[CONSUMO ENERGÉTICO] RELAÇÃO DEFESA X ATAQUE 1 / 0.7",
#     subtitle="Tamanho da Amostra: 200 | Bootstrap: 10.000 iterações",
#     xlabel="Razão numérica entre drones Defensivos e Atacantes",
#     ylabel="Índice de Consumo Energético",
#     n_bootstrap=10_000,
#     alpha=0.01,
#     figsize=(12, 7),
#     split=True,
#     gap=0.03,
#     fill=True,
#     linewidth=1.5,
#     width=0.5,
#     palette=["m", "g"],
#     common_norm=True,
#     density_norm="area",
#     save_fig=True,
#     save_dir="../analysis/images",
#     filename="CONSUMO_ENERGETICO_RELACAO_1_0.7",
#     legend_title='Atacante em\n Formação',
#     legend_labels={True: 'Sim', False: 'Não'},
#     inner="quart",                      # Quartis visíveis
#     x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198'],  # ← Aplicar sua ordem
#     ylim_bottom=-5000,
#     # ylim_top=5000
# )

# %% [markdown]
# #### Sumarização

# %%
# Chamada da função com GAP entre hemisférios
test_result = violinplot_with_overlap(
    data=data,
    filter_conditions=None,
    x_col="simulation",
    y_col="total_distance_traveled", 
    hue_col="formation",
    hue2_col="ratio friend:enemy",
    title="[CONSUMO ENERGÉTICO] COMPARAÇÃO ENTRE RELAÇÕES DEFESA X ATAQUE",
    subtitle="Linha sólida/pontilhada: Formação | Cores: Algoritmo",
    xlabel="Razão numérica entre drones Defensivos e Atacantes",
    ylabel="Índice de Consumo Energético",
    figsize=(14, 8),  
    linewidth=0.5,  
    palette=None,  
    hue2_palette=None,  
    save_fig=True,
    save_dir="../analysis/images",
    filename="CONSUMO_ENERGETICO_COMPARACAO_RELACOES",
    legend_title='Atacante em\n Formação',
    legend_labels={True: 'Sim', False: 'Não'},
    hue2_legend_title="Tipo de Simulação",  
    x_order=['baseline (TG)', 'baseline (naive)', 'behavior_clone_8198', 'behavior_clone_32768', 'behavior_clone_131072'],  # ← Aplicar sua ordem
    hue2_order=None,  
    ylim_top=80000,
    ylim_bottom=0,
    hemisphere_mode='split',
    loc='upper right'
)
